# %%
import pandas as pd
import os

# %%
def combine_the_trafic_file(root_dir):
   
    for parent in sorted(os.listdir(root_dir)):
       parent_path =  os.path.join(root_dir, parent)
       print(parent_path)
       #all_data =pd.DataFrame()
       for sub_file in sorted(os.listdir(parent_path)):
          child_path = os.path.join(parent_path, sub_file)
          print(child_path)
          if child_path.endswith(".xlsx"):
             df = pd.read_excel(child_path)
             print(df.head())
             
      
    combined_df = pd.concat(all_data, ignore_index=True)  
    combined_df.write_parquet(root_dir , compression="zstd")
          

combine_the_trafic_file('/Users/thomas/Data/Dynamic_weight_data/Marzo')
# Out:
# /Users/thomas/Data/Dynamic_weight_data/Marzo/1 marzo - 7 marzo
# /Users/thomas/Data/Dynamic_weight_data/Marzo/1 marzo - 7 marzo/1.xlsx
#        Id      StartTime         StartTimeStr  LaneNo  \
# 0  634497  1740790000000  2025-01-03 00:58:00       2
# 1  634563  1740790000000  2025-01-03 01:54:00       3
# 2  675479  1740960000000  2025-03-03 00:16:00       2
# 3  675556  1740960000000  2025-03-03 01:21:00       2
# 4  696920  1741050000000  2025-04-03 00:25:00       2
#
#                    LaneName  BaseClassId Scheme  ClassId  MoveStatus  \
# 0         Corsia 1 - Marcia           19  EUR13       12          -1
# 1  Corsia 2 - Marcia veloce           22  EUR13        2          -1
# 2         Corsia 1 - Marcia            4  EUR13        3           1
# 3         Corsia 1 - Marcia           14  EUR13        8           1
# 4         Corsia 1 - Marcia           21  EUR13        1          -1
#
#    FrontToFront  ...  WheelBase  FrontOverhang  AxlesCount  MassUnit  \
# ...
